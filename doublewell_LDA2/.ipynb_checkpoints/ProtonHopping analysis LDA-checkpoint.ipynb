# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sep_mult=np.arange(4,9,1)
separations=sep_mult*0.719643*2
positions=[[j*0.71964 -separations[i]/2 for j in range(1,sep_mult[i]+1)] for i in range(size(sep_mult))]

# %%
sep_mult=np.arange(0,5,1)

# %%
separations2=[0.6477,0.6837,0.7196,0.7556,0.7916]
positions2=[[-2.1590,-1.4393,-0.7197,-0.0000],[-2.8786,-2.1589,-1.4393,-0.7196,0.0000],[-3.5983,-2.8786,-2.1590,-1.4393,-0.7197,-0.0000],[-4.3179,-3.5982,-2.8786,-2.1589,-1.4393,-0.7196,0.0000],[-5.0375,-4.3178,-3.5982,-2.8785,-2.1589,-1.4392,-0.7196,0.0000]]

# %%
positions2=[[0.0000,0.1295,0.2591 ,0.3886 ,0.5182],[0.0000,0.1367,0.2735,0.4102,0.5470],[0.0000,0.1439,0.2878,0.4318,
0.5757],[0.0000, 0.1511, 0.3022, 0.4534, 0.6045],[0.0000,0.1583,0.3166,0.4750,0.6333 ]]

# %%
Energy_curves=[]
Pos=[]
for i in range(5):
    energy_prime=[]
    for j in range(0,5):
        #print(i,j,separations2[i],positions2[i][j])
        with open(str('%.4f' % separations2[i])+"_"+str('%.4f' %positions2[i][j])+"_H2.Ecomponents") as f:
            lineList = f.readlines()
        energy_prime.append(float(lineList[-1].split()[-1]))
        #print(energy_prime)
    #k=2*sep_mult[i]-1
    #print(k)
    #with open(str('%.4f' % separations2[i])+"_"+str('%.4f' %positions2[i][k])+"_H2.Ecomponents") as f:
            #lineList = f.readlines()
            
    #x0=float(float(lineList[-1].split()[-1]))
    Energy_curves.append(energy_prime[::-1]+energy_prime[1:])
    Pos.append(list(-np.array(positions2[i]))[::-1]+positions2[i][1:])
    #print(Pos[i],Energy_curves[i] ,'\n')

# %%
for i in range(size(sep_mult)):
    plot(Pos[i], Energy_curves[i],label=r'$\delta r/2 =$'+str('%.4f' % separations2[i])+' B')
    plt.legend(loc='upper center')
    plt.xlabel('free H position (B)')
    plt.ylabel('energy (Hartree)')

# %%
for i in range(size(sep_mult)):
    print(Energy_curves[i])
# Out:
# [4.898378464598158, 1.1157483587811226, -0.0463852540911323, -0.5115227953616828, -0.6413894580517128, -0.5115227953616828, -0.0463852540911323, 1.1157483587811226, 4.898378464598158]
# [4.467597280519415, 0.8871610655077924, -0.2096251084706746, -0.6467221175212385, -0.7683844094141723, -0.6467221175212385, -0.2096251084706746, 0.8871610655077924, 4.467597280519415]
# [4.082197119602634, 0.6857909814416852, -0.3522695957185054, -0.7631283305288041, -0.8771718808805609, -0.7631283305288041, -0.3522695957185054, 0.6857909814416852, 4.082197119602634]
# [3.7352407040266575, 0.5050346042445382, -0.4778301233940396, -0.8644613198058957, -0.9712955659397904, -0.8644613198058957, -0.4778301233940396, 0.5050346042445382, 3.7352407040266575]
# [3.4212802128423485, 0.3429804040831166, -0.5888152374525137, -0.9527692412274216, -1.0528167996714122, -0.9527692412274216, -0.5888152374525137, 0.3429804040831166, 3.4212802128423485]

# %%
sep_mult=np.arange(4,9,1)
separations=sep_mult*0.719643*2
positions=[[j*0.71964/2 -separations[i]/2 for j in range(1,2*sep_mult[i]+1)] for i in range(size(sep_mult))]

# %%
positions2=[[-2.5188,
-2.1590,
-1.7991,
-1.4393,
-1.0795,
-0.7197,
-0.3598,
-0.0000],
[-3.2384,
-2.8786,
-2.5187,
-2.1589,
-1.7991,
-1.4393,
-1.0794,
-0.7196,
-0.3598,
0.0000 
],
[-3.9581,
-3.5983,
-3.2384,
-2.8786,
-2.5188,
-2.1590,
-1.7991,
-1.4393,
-1.0795,
-0.7197,
-0.3599,
-0.0000
],
[-4.6777,
-4.3179,
-3.9580,
-3.5982,
-3.2384,
-2.8786,
-2.5187,
-2.1589,
-1.7991,
-1.4393,
-1.0795,
-0.7196,
-0.3598,
0.0000 
],
[-5.3973,
-5.0375,
-4.6776,
-4.3178,
-3.9580,
-3.5982,
-3.2383,
-2.8785,
-2.5187,
-2.1589,
-1.7991,
-1.4392,
-1.0794,
-0.7196,
-0.3598,
0.0000   
]]

# %%
with open("3.5982_-0.3598_H2.Ecomponents") as f:
    lineList = f.readlines()
            
x0=float(float(lineList[-1].split()[-1]))

# %%
x0
